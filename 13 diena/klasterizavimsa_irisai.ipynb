# %%
# Klasterizavimas k-mean. irisai
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/moksliukas/VMI_data/main/13%20diena/data/iris.csv')
y=df

# %%
df=df.drop(columns='Name')
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
plt.scatter(df['SepalLength'],df['SepalWidth'])

# %%
sse=[]
for k in range(1,11):
    kmeans=KMeans(n_clusters=k)
    kmeans.fit(df)
    sse.append(kmeans.inertia_)
    
plt.plot(range(1,11), sse)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sil=[]
for k in range(2,11):
    kmeans=KMeans(n_clusters=k)
    kmeans.fit(df)
    sil.append(silhouette_score(df, kmeans.labels_))
    
plt.plot(range(2,11), sil)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
kmeans=KMeans(n_clusters=3)
kmeans.fit(df)
y=kmeans.predict(df)

# %%
plt.scatter(df['SepalLength'],df['SepalWidth'], c=y, cmap='viridis')
centers=kmeans.cluster_centers_
plt.scatter(centers[:,0], centers[:,1], c='red', s=200, alpha=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
