# %%
import warnings
import pandas as pd
warnings.filterwarnings('ignore')

# %%
file="https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/titanic.csv"
titaniko_keleiviai=pd.read_csv(file)

# %%
titaniko_keleiviai.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titaniko_keleiviai.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titaniko_keleiviai.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titaniko_keleiviai['Age'].mean()
# Out:
# 29.69911764705882

# %%
titaniko_keleiviai.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
pl_kelias="data/pardavimo planas.xlsx"
kelias1="C:\\Users\\sprei\\OneDrive\\01-Dideli mokymai\\VMI mokymai\\Python kodai\\Python 2\\data\\pardavimo planas.xlsx"
pardavimo_planas=pd.read_excel(kelias1, sheet_name='Planas')

# %%
pardavimo_planas.head()
# Out:
#   parduotuves_pavadinimas  Planas Mėnesio pradžia
# 0                 Store 1    1033      1998-01-01
# 1                 Store 1    3008      1998-02-01
# 2                 Store 1     358      1998-03-01
# 3                 Store 1    2057      1998-04-01
# 4                 Store 1    1233      1998-05-01

# %%
amzius_lytis=titaniko_keleiviai[['Age','Sex']]

# %%
amzius_lytis[amzius_lytis['Age']>35]
titaniko_keleiviai.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titaniko_keleiviai[titaniko_keleiviai['Pclass'].isin([2,3])]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
titaniko_keleiviai.shape
# Out:
# (891, 12)

# %%
amzius_sutvarkytas=titaniko_keleiviai[titaniko_keleiviai['Age'].notna()]

# %%
amzius_sutvarkytas.shape
# Out:
# (714, 12)

# %%
motery_1_klase=titaniko_keleiviai.loc[titaniko_keleiviai['Pclass']==1,['Name','Age']]

# %%
motery_1_klase
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 6                              McCarthy, Mr. Timothy J  54.0
# 11                            Bonnell, Miss. Elizabeth  58.0
# 23                        Sloper, Mr. William Thompson  28.0
# ..                                                 ...   ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0
# 872                           Carlsson, Mr. Frans Olof  33.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 889                              Behr, Mr. Karl Howell  26.0
#
# [216 rows x 2 columns]

# %%
failas='data/air_quality_no2.csv'
oras_df=pd.read_csv(failas, index_col=0, parse_dates=True)

# %%
oras_df
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 3 columns]

# %%
oras_df.plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
import matplotlib.pyplot as plt

# %%
oras_df['station_paris'].plot()
plt.title('Paryziaus oras')
plt.show()

# %%
titaniko_keleiviai
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
k=titaniko_keleiviai[['PassengerId','Sex']].groupby('Sex').count()
k.plot.bar()
# Out:
# <Axes: xlabel='Sex'>
