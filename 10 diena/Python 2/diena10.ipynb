# %%
import pandas as pd
kelias="data/dimKlientai.csv"
df=pd.read_csv(kelias, sep=";")

# %%
df.head()
# Out:
#    kliento_id  kliento_sask_nr   vardas    pavarde     kliento_adresas  \
# 0           1      87462024688    Sheri     Nowmer    2433 Bailey Road
# 1           2      87470586299  Derrick    Whelply  2219 Dewing Avenue
# 2           3      87475757600   Jeanne      Derry     7640 First Ave.
# 3           4      87500482201  Michael     Spence       337 Tosca Way
# 4           5      87514054179     Maya  Gutierrez     8668 Via Neruda
#
#   kliento_miestas kliento_provincija  kliento_pasto_kodas kliento_salis  \
# 0        Tlaxiaco             Oaxaca                15057        Mexico
# 1           Sooke                 BC                17172        Canada
# 2        Issaquah                 WA                73980           USA
# 3         Burnaby                 BC                74674        Canada
# 4          Novato                 CA                57355           USA
#
#   gimimo_data seimynine_padetis metines_pajamos lytis  vaiku_skaicius  \
# ...

# %%
df.dtypes
# Out:
# kliento_id                     int64
# kliento_sask_nr                int64
# vardas                        object
# pavarde                       object
# kliento_adresas               object
# kliento_miestas               object
# kliento_provincija            object
# kliento_pasto_kodas            int64
# kliento_salis                 object
# gimimo_data                   object
# seimynine_padetis             object
# metines_pajamos               object
# lytis                         object
# vaiku_skaicius                 int64
# vaiku_skaicius_namuose         int64
# issilavinimas                 object
# kliento_registracijos_data    object
# kliento_kortele               object
# uzsiemimas                    object
# namu_savininkas               object
# dtype: object

# %%
df["vaiku_skaicius"].mean()
# Out:
# 2.502917720287882

# %%
df.describe()
# Out:
#          kliento_id  kliento_sask_nr  kliento_pasto_kodas  vaiku_skaicius  \
# count  10282.000000     1.028200e+04         10282.000000    10282.000000
# mean    5141.500000     5.032605e+10         55313.712702        2.502918
# std     2968.302068     2.534535e+10         26133.715490        1.500524
# min        1.000000     1.001355e+10          1374.000000        0.000000
# 25%     2571.250000     2.836187e+10         32760.000000        1.000000
# 50%     5141.500000     4.850338e+10         55290.500000        3.000000
# 75%     7711.750000     7.088049e+10         78207.500000        4.000000
# max    10282.000000     9.996103e+10         99993.000000        5.000000
#
#        vaiku_skaicius_namuose
# count            10282.000000
# mean                 0.814530
# std                  1.294542
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  1.000000
# max                  5.000000
