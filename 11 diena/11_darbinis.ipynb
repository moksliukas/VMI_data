# %%
import pandas as pd

# %%
titanic_df=pd.read_csv('data/titanic.csv')

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.sort_values(by=['Pclass','Sex'], ascending=False).head(100)
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# ..           ...       ...     ...                             ...   ...
# 231          232         0       3        Larsson, Mr. Bengt Edvin  male
# 243          244         0       3   Maenpaa, Mr. Matti Alexanteri  male
# 244          245         0       3            Attalah, Mr. Sleiman  male
# 250          251         0       3          Reed, Mr. James George  male
# 253          254         0       3        Lobb, Mr. William Arthur  male
#
#       Age  SibSp  Parch             Ticket     Fare Cabin Embarked
# ...

# %%
air_qual=pd.read_csv('data/air_quality_long.csv', index_col='date.utc', parse_dates=True)

# %%
air_qual
# Out:
#                                 city country            location parameter  \
# date.utc
# 2019-06-18 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 08:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 07:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 05:00:00+00:00  Antwerpen      BE             BETR801      pm25
# ...                              ...     ...                 ...       ...
# 2019-04-09 06:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 05:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 04:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 03:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00     London      GB  London Westminster       no2
#
#                            value   unit
# date.utc
# ...

# %%
sub_air_qual=air_qual.pivot(columns='location',values='value')
sub_air_qual
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sub_air_qual=air_qual.pivot(columns='location',values='value')
#       2 sub_air_qual
#
# File ~\anaconda3\envs\Mokymai_VMI_1\Lib\site-packages\pandas\core\frame.py:9028, in DataFrame.pivot(self, columns, index, values)
#    9021 @Substitution("")
#    9022 @Appender(_shared_docs["pivot"])
#    9023 def pivot(
#    9024     self, *, columns, index=lib.no_default, values=lib.no_default
#    9025 ) -> DataFrame:
#    9026     from pandas.core.reshape.pivot import pivot
# -> 9028     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\anaconda3\envs\Mokymai_VMI_1\Lib\site-packages\pandas\core\reshape\pivot.py:553, in pivot(data, columns, index, values)
#     549         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# ...

# %%
air_qual.head()
# Out:
#                                 city country location parameter  value   unit
# date.utc
# 2019-06-18 06:00:00+00:00  Antwerpen      BE  BETR801      pm25   18.0  µg/m³
# 2019-06-17 08:00:00+00:00  Antwerpen      BE  BETR801      pm25    6.5  µg/m³
# 2019-06-17 07:00:00+00:00  Antwerpen      BE  BETR801      pm25   18.5  µg/m³
# 2019-06-17 06:00:00+00:00  Antwerpen      BE  BETR801      pm25   16.0  µg/m³
# 2019-06-17 05:00:00+00:00  Antwerpen      BE  BETR801      pm25    7.5  µg/m³

# %%
air_qual.pivot_table(
    values='value',
    index=['country','location'],
    columns='parameter',
    aggfunc='mean',
    margins=True
).plot.bar(legend=True, title='Užterštumas')
# Out:
# <Axes: title={'center': 'Užterštumas'}, xlabel='country,location'>
